# %%
#!git clone https://github.com/meituan/YOLOv6

# %%
cd YOLOv6
# Out:
# /content/YOLOv6

# %%
# !pip install -r requirements.txt
# AssertionError: Torch not compiled with CUDA enabled

# This requirement file is not installing torch with cuda. So if you want to train your model using gpu then install torch with cuda

# Below torch version works with rtx 3090 (cuda 11.1)
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html

# !pip install addict

# %%
import torch
torch.cuda.is_available() 
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
#!unzip ../NEU-DET-YOLOV5.zip

# %% [markdown]
# # **Training**

# %%
# !python tools/train.py --batch 32 --conf configs/yolov6s.py --data-path dataset/data.yaml --device 0 --epochs 300  --eval-interval 2
# Out:
# Using 1 GPU for training...
# training args are: Namespace(batch_size=32, calib=False, check_images=False, check_labels=False, conf_file='configs/yolov6s.py', data_path='dataset/data.yaml', device='0', dist_url='env://', distill=False, distill_feat=False, epochs=300, eval_final_only=False, eval_interval=2, gpu_count=0, heavy_eval_range=50, img_size=640, local_rank=-1, name='exp', output_dir='./runs/train', quant=False, rank=-1, resume=False, save_ckpt_on_last_n_epoch=-1, save_dir='runs/train/exp1', stop_aug_last_n_epoch=15, teacher_model_path=None, temperature=20, workers=8, world_size=1, write_trainbatch_tb=False)
#
# Train: Final numbers of valid images: 1439/ labels: 1439.
# 0.0s for dataset initialization.
# Convert to COCO format
# 100% 360/360 [00:00<00:00, 81835.64it/s]
# Convert to COCO format finished. Resutls saved in dataset/annotations/instances_val.json
# Val: Final numbers of valid images: 360/ labels: 360.
# 0.1s for dataset initialization.
# Model: Model(
# ...

# %%
# !zip -r /content/YOLOv6.zip /content/YOLOv6

# %% [markdown]
# # **Evaluation**

# %%
#!python tools/eval.py --data dataset.yaml  --weights run/train/exp7/weights/best_ckpt.pt --device 0

# %% [markdown]
# # **Inference**

# %%
#cd YOLOv6
# !python tools/infer.py --weights runs/train/exp7/weights/best_ckpt.pt --source test_images/1.jpg --yaml dataset.yaml --device 0

# %% [markdown]
# # **Prediction**

# %%
from IPython.display import Image #this is to render predictions
Image(filename='runs/inference/exp/1.jpg', width=1000)
